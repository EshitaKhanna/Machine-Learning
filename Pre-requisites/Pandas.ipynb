# %%
import pandas as pd
import numpy as np

# %%
dib_df = pd.read_csv("/Users/Eshita/Desktop/Stuff/ML/Datasets/diabetes.csv")

# %%
dib_df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
type(dib_df), dib_df.shape
# Out:
# (pandas.core.frame.DataFrame, (768, 9))

# %%
# print first 5 rows
dib_df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
# print last 5 rows
dib_df.tail()
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 763                     0.171   63        0
# 764                     0.340   27        0
# 765                     0.245   30        0
# 766                     0.349   47        1
# 767                     0.315   23        0

# %% [markdown]
# Creating a DataFrame with random values

# %%
random_df = pd.DataFrame(np.random.rand(10,20))
random_df
# Out:
#          0         1         2         3         4         5         6   \
# 0  0.621726  0.331722  0.930119  0.728831  0.095880  0.379642  0.189606
# 1  0.566979  0.657743  0.276994  0.425654  0.201422  0.078664  0.988272
# 2  0.213342  0.311120  0.594853  0.363303  0.862096  0.988967  0.543643
# 3  0.872874  0.537076  0.662831  0.003678  0.849686  0.636876  0.004158
# 4  0.923938  0.230843  0.587067  0.032107  0.507438  0.770130  0.892389
# 5  0.351400  0.371589  0.699735  0.185232  0.847716  0.999302  0.443047
# 6  0.163981  0.559106  0.487215  0.907770  0.809427  0.286551  0.938162
# 7  0.587547  0.928329  0.799435  0.564958  0.606244  0.871880  0.238334
# 8  0.713424  0.227897  0.092511  0.666770  0.308732  0.219793  0.457365
# 9  0.613848  0.095769  0.066346  0.794483  0.459674  0.305499  0.434304
#
#          7         8         9         10        11        12        13  \
# 0  0.065694  0.509514  0.464224  0.101139  0.349486  0.346179  0.840946
# ...

# %%
random_df.shape
# Out:
# (10, 20)

# %%
# information of the data frame
dib_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %%
# to find number of missing values
dib_df.isnull().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
# counting the values based on labels
dib_df.value_counts('Outcome')
# Out:
# Outcome
# 0    500
# 1    268
# Name: count, dtype: int64

# %%
# grouping values based on mean
dib_df.groupby('Outcome').mean()
# Out:
#          Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# Outcome
# 0           3.298000  109.980000      68.184000      19.664000   68.792000
# 1           4.865672  141.257463      70.824627      22.164179  100.335821
#
#                BMI  DiabetesPedigreeFunction        Age
# Outcome
# 0        30.304200                  0.429734  31.190000
# 1        35.142537                  0.550500  37.067164

# %% [markdown]
# Statistical Measures

# %%
housing_df = pd.read_csv('/Users/Eshita/Desktop/Stuff/ML/Datasets/housing.csv')
housing_df.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY
# 3       558.0       219.0         5.6431            341300.0        NEAR BAY
# 4       565.0       259.0         3.8462            342200.0        NEAR BAY

# %%
# count number of values
housing_df.count()
# Out:
# longitude             20640
# latitude              20640
# housing_median_age    20640
# total_rooms           20640
# total_bedrooms        20433
# population            20640
# households            20640
# median_income         20640
# median_house_value    20640
# ocean_proximity       20640
# dtype: int64

# %%
# mean - coulmn wise
housing_df.mean()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File /opt/homebrew/lib/python3.11/site-packages/pandas/core/nanops.py:1680, in _ensure_numeric(x)
#    1679 try:
# -> 1680     x = x.astype(np.complex128)
#    1681 except (TypeError, ValueError):
#
# ValueError: complex() arg is a malformed string
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# File /opt/homebrew/lib/python3.11/site-packages/pandas/core/nanops.py:1683, in _ensure_numeric(x)
#    1682 try:
# -> 1683     x = x.astype(np.float64)
#    1684 except ValueError as err:
#    1685     # GH#29941 we get here with object arrays containing strs
#
# ...

# %%
# standard deviation - coulmn wise
housing_df.std()
# Out:
# CRIM         8.720192
# ZN          23.388876
# INDUS        6.835896
# CHAS         0.255340
# NOX          0.115878
# RM           0.702617
# AGE         27.999513
# DIS          2.105710
# RAD          8.707259
# TAX        168.537116
# PTRATIO      2.164946
# B           91.294864
# LSTAT        7.155871
# MEDV         9.197104
# dtype: float64

# %%
# minimum values - coulmn wise
housing_df.min()
# Out:
# CRIM         0.00632
# ZN           0.00000
# INDUS        0.46000
# CHAS         0.00000
# NOX          0.38500
# RM           3.56100
# AGE          2.90000
# DIS          1.12960
# RAD          1.00000
# TAX        187.00000
# PTRATIO     12.60000
# B            0.32000
# LSTAT        1.73000
# MEDV         5.00000
# dtype: float64

# %%
# maximum values - coulmn wise
housing_df.max()
# Out:
# CRIM        88.9762
# ZN         100.0000
# INDUS       27.7400
# CHAS         1.0000
# NOX          0.8710
# RM           8.7800
# AGE        100.0000
# DIS         12.1265
# RAD         24.0000
# TAX        711.0000
# PTRATIO     22.0000
# B          396.9000
# LSTAT       37.9700
# MEDV        50.0000
# dtype: float64

# %%
# all statistical measures of the dataframe
housing_df.describe()
# Out:
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  486.000000  486.000000  486.000000  486.000000  506.000000  506.000000
# mean     3.611874   11.211934   11.083992    0.069959    0.554695    6.284634
# std      8.720192   23.388876    6.835896    0.255340    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.081900    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.253715    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.560263   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               AGE         DIS         RAD         TAX     PTRATIO           B  \
# count  486.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.518519    3.795043    9.549407  408.237154   18.455534  356.674032
# ...

# %% [markdown]
# Manipulating Dataframe

# %%
# remove a column
housing_df.drop(index=0, axis=0)
# Out:
#         CRIM   ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  PTRATIO  \
# 1    0.02731  0.0   7.07   0.0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2    0.02729  0.0   7.07   0.0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3    0.03237  0.0   2.18   0.0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4    0.06905  0.0   2.18   0.0  0.458  7.147  54.2  6.0622    3  222     18.7
# 5    0.02985  0.0   2.18   0.0  0.458  6.430  58.7  6.0622    3  222     18.7
# ..       ...  ...    ...   ...    ...    ...   ...     ...  ...  ...      ...
# 501  0.06263  0.0  11.93   0.0  0.573  6.593  69.1  2.4786    1  273     21.0
# 502  0.04527  0.0  11.93   0.0  0.573  6.120  76.7  2.2875    1  273     21.0
# 503  0.06076  0.0  11.93   0.0  0.573  6.976  91.0  2.1675    1  273     21.0
# 504  0.10959  0.0  11.93   0.0  0.573  6.794  89.3  2.3889    1  273     21.0
# 505  0.04741  0.0  11.93   0.0  0.573  6.030   NaN  2.5050    1  273     21.0
#
#           B  LSTAT  MEDV
# ...

# %%
# drop column
housing_df.drop(columns = 'ocean_proximity', axis = 1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /Users/Eshita/Desktop/Stuff/ML/Pre-requistes/Pandas.ipynb Cell 24 line 2
#       <a href='vscode-notebook-cell:/Users/Eshita/Desktop/Stuff/ML/Pre-requistes/Pandas.ipynb#X32sZmlsZQ%3D%3D?line=0'>1</a> # drop column
# ----> <a href='vscode-notebook-cell:/Users/Eshita/Desktop/Stuff/ML/Pre-requistes/Pandas.ipynb#X32sZmlsZQ%3D%3D?line=1'>2</a> housing_df.drop(columns = 'ocean_proximity', axis = 1)
#
# File /opt/homebrew/lib/python3.11/site-packages/pandas/core/frame.py:5258, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5110 def drop(
#    5111     self,
#    5112     labels: IndexLabel = None,
#    (...)
#    5119     errors: IgnoreRaise = "raise",
#    5120 ) -> DataFrame | None:
#    5121     """
#    5122     Drop specified labels from rows or columns.
#    5123
#    (...)
# ...

# %%
# locating a row using index value
housing_df.iloc[2]
# Out:
# longitude              -122.24
# latitude                 37.85
# housing_median_age        52.0
# total_rooms             1467.0
# total_bedrooms           190.0
# population               496.0
# households               177.0
# median_income           7.2574
# median_house_value    352100.0
# ocean_proximity       NEAR BAY
# Name: 2, dtype: object

# %%
# locating a column using index value
print(housing_df.iloc[:,1]) # prints 2nd column
print(housing_df.iloc[:,-1]) # prints last column
# Out:
# 0        37.88
# 1        37.86
# 2        37.85
# 3        37.85
# 4        37.85
#          ...
# 20635    39.48
# 20636    39.49
# 20637    39.43
# 20638    39.43
# 20639    39.37
# Name: latitude, Length: 20640, dtype: float64
# 0        NEAR BAY
# 1        NEAR BAY
# 2        NEAR BAY
# 3        NEAR BAY
# 4        NEAR BAY
#            ...
# 20635      INLAND
# 20636      INLAND
# 20637      INLAND
# 20638      INLAND
# 20639      INLAND
# Name: ocean_proximity, Length: 20640, dtype: object

# %% [markdown]
# Correlation

# %%
housing_df.corr()
# Out:
# <ipython-input-36-efd18c3aa5ce>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   housing_df.corr()
#                     longitude  latitude  housing_median_age  total_rooms  \
# longitude            1.000000 -0.924664           -0.108197     0.044568
# latitude            -0.924664  1.000000            0.011173    -0.036100
# housing_median_age  -0.108197  0.011173            1.000000    -0.361262
# total_rooms          0.044568 -0.036100           -0.361262     1.000000
# total_bedrooms       0.069608 -0.066983           -0.320451     0.930380
# population           0.099773 -0.108785           -0.296244     0.857126
# households           0.055310 -0.071035           -0.302916     0.918484
# median_income       -0.015176 -0.079809           -0.119034     0.198050
# ...
