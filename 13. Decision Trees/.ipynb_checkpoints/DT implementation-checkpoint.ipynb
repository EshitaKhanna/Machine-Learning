# %%
import numpy as np
from sklearn.datasets import load_iris
from sklearn.tree import export_graphviz
import pydotplus
from IPython.display import Image

# %%
def entropy(Y):
    _, class_counts = np.unique(Y, return_counts = True)
    prob = class_counts/ len(Y)
    prob = prob[prob > 0]  # Avoid log(0)
    entropy = - np.sum(prob * np.log2(prob))

    return entropy

# %%
def info_gain(X, Y, feature):
    # identify Unique Values of the Feature
    unique_values = np.unique(X[:, feature])
    weighted_entropy = 0

    for value in unique_values:
        y_row = Y[X[:, feature] == value]
        weighted_entropy += (len(y_row) / len(Y)) * entropy(y_row)

    gain = entropy(Y) - weighted_entropy

    return gain

# %%
def intrinsic_value(X, selected_feature):
    unique_values = np.unique(X[:, selected_feature])
    iv = 0

    for value in unique_values:
        subset = X[X[:, selected_feature] == value]
        prob = len(subset) / len(X)
        iv -= prob * np.log2(prob)

    return iv

def gain_ratio(X, Y, selected_feature):
    gain = info_gain(X, Y, selected_feature)
    iv = intrinsic_value(X, selected_feature)
    if iv == 0:
        return 0
    return gain / iv

# %%
# def best_feature(X, Y):
#     num_features = X.shape[1]
#     gains = np.zeros(num_features)
    
#     for feature in range(num_features):
#         gains[feature] = info_gain(X, Y, feature)
        
#     best_feature = np.argmax(gains)
#     return best_feature

def best_feature(X, Y):
    num_features = X.shape[1]
    gain_ratios = np.zeros(num_features)

    for feature in range(num_features):
        gain_ratios[feature] = gain_ratio(X, Y, feature)

    best_feature = np.argmax(gain_ratios)
    return best_feature, gain_ratios[best_feature]

# %%
class Node:
    def __init__(self, feature = None, threshold = None, left = None, right = None, value = None):
        # for decision node
        self.feature = feature
        self.threshold = threshold
        self.left = left
        self.right = right
        
        # for leaf node
        self.value = value

# %%
def build_tree(X, Y):
    # if pure node
    if len(set(Y)) == 1 or X.shape[1] == 0:
        return Node(value=np.bincount(Y).argmax())
        
    # # if no features are left to be split, return leaf node with majority decision
    # if X.shape[1] == 0:
    #     return Node(value=np.bincount(Y).argmax())
    
    # Find the best feature to split on
    best_feat, best_gain_ratio = best_feature(X, Y)
    best_threshold = np.unique(X[:, best_feat])[0]  # Use the first unique value as the threshold
    
    # Split the dataset based on best feature
    left_indices = X[:, best_feat] == best_threshold
    right_indices = ~left_indices

    # Check if there are no elements in left or right
    if len(Y[left_indices]) == 0 or len(Y[right_indices]) == 0:   
        return Node(value=np.bincount(Y).argmax())  # Return majority class if no split possible
    
    # Recursively build the left and right subtrees
    left_subtree = build_tree(X[left_indices], Y[left_indices])
    right_subtree = build_tree(X[right_indices], Y[right_indices])
    
    # Return the decision node with its children
    return Node(feature=best_feat, threshold=best_threshold, left=left_subtree, right=right_subtree, value=best_gain_ratio)

# %%
'''
function showDecisionTree(data_node, output, features, level):
    
    total_elements = length(data_node)
    no_of_setosa, no_of_versicolor = countSetosa(output), countVersicolor(output)
    no_of_virginica = total_elements - no_of_setosa - no_of_versicolor
    
    print "Level", level
    print "Setosa:", no_of_setosa, "Versicolor:", no_of_versicolor, "Virginica:", no_of_virginica
    print "Entropy:", entropy(output)
    
    if stoppingCondition(no_of_setosa, no_of_versicolor, no_of_virginica, length(features)):
        print "Reached leaf node"
        return createLeafNode(entropy(output), level, majorityClass(no_of_setosa, no_of_versicolor, no_of_virginica))
    
    feature, max_gain_ratio, imp = FeatureSplitting(data_node, features, output)
    print "Splitting on feature", feature, "with gain ratio", max_gain_ratio
    root = createNode(entropy(output), level, feature, max_gain_ratio, majorityClass(no_of_setosa, no_of_versicolor, no_of_virginica))
    
    data1, data2, out1, out2 = splitData(data_node, output, feature, imp)
    root.left = showDecisionTree(data1, out1, features, level + 1)
    root.right = showDecisionTree(data2, out2, features, level + 1)
    
    return root
'''
# Out:
# '\nfunction showDecisionTree(data_node, output, features, level):\n    \n    total_elements = length(data_node)\n    no_of_setosa, no_of_versicolor = countSetosa(output), countVersicolor(output)\n    no_of_virginica = total_elements - no_of_setosa - no_of_versicolor\n    \n    print "Level", level\n    print "Setosa:", no_of_setosa, "Versicolor:", no_of_versicolor, "Virginica:", no_of_virginica\n    print "Entropy:", entropy(output)\n    \n    if stoppingCondition(no_of_setosa, no_of_versicolor, no_of_virginica, length(features)):\n        print "Reached leaf node"\n        return createLeafNode(entropy(output), level, majorityClass(no_of_setosa, no_of_versicolor, no_of_virginica))\n    \n    feature, max_gain_ratio, imp = FeatureSplitting(data_node, features, output)\n    print "Splitting on feature", feature, "with gain ratio", max_gain_ratio\n    root = createNode(entropy(output), level, feature, max_gain_ratio, majorityClass(no_of_setosa, no_of_versicolor, no_of_virginica))\n    \n    data1, data2, out1, out2 = splitData(data_node, output, feature, imp)\n    root.left = showDecisionTree(data1, out1, features, level + 1)\n    root.right = showDecisionTree(data2, out2, features, level + 1)\n    \n    return root\n'

# %%
def print_tree(node, X, Y, depth=0):
    total_elements = len(Y)
    class_counts = np.bincount(Y, minlength=3)

    print(f"Level {depth}")
    for i, count in enumerate(class_counts):
        print(f"Count of {i} = {count}")
    print(f"Current Entropy is = {entropy(Y):.6f}")

    if node.value is not None and node.feature is None:
        print(f"Reached leaf Node")
        return

    print(f"Splitting on feature {node.feature} with gain ratio {node.value}")

    left_indices = X[:, node.feature] == node.threshold
    right_indices = ~left_indices

    if len(X[left_indices]) == 0 or len(X[right_indices]) == 0:
        print(f"Reached leaf Node")
        return

    print_tree(node.left, X[left_indices], Y[left_indices], depth + 1)
    print_tree(node.right, X[right_indices], Y[right_indices], depth + 1)

# %%
def predict(node, sample):
    while node.left or node.right:
        if sample[node.feature] == node.threshold:
            node = node.left
        else:
            node = node.right
    return node.value

def score(node, X, Y):
    predictions = [predict(node, sample) for sample in X]
    accuracy = np.sum(predictions == Y) / len(Y)
    return accuracy

# %%
# Load the Iris dataset
iris = load_iris()
X = iris.data
Y = iris.target

from sklearn import model_selection
X_train, X_test, Y_train, Y_test = model_selection.train_test_split(X,Y, random_state = 1)

# Build the decision tree
decision_tree = build_tree(X_train, Y_train)

# Print the decision tree
print("Decision Tree:")
print_tree(decision_tree, X_train, Y_train)

# Evaluate the decision tree
train_accuracy = score(decision_tree, X_train, Y_train)
test_accuracy = score(decision_tree, X_test, Y_test)

print(f"\nTrain Accuracy: {train_accuracy:.2f}")
print(f"Test Accuracy: {test_accuracy:.2f}")
# Out:
# Decision Tree:
# Level 0
# Count of 0 = 37
# Count of 1 = 34
# Count of 2 = 41
# Current Entropy is = 1.580720
# Splitting on feature 3 with gain ratio 0.35471104425168914
# Level 1
# Count of 0 = 5
# Count of 1 = 0
# Count of 2 = 0
# Current Entropy is = -0.000000
# Reached leaf Node
# Level 1
# Count of 0 = 32
# Count of 1 = 34
# Count of 2 = 41
# Current Entropy is = 1.576669
# Splitting on feature 3 with gain ratio 0.3597686303473294
# Level 2
# Count of 0 = 22
# Count of 1 = 0
# Count of 2 = 0
# Current Entropy is = -0.000000
# Reached leaf Node
# Level 2
# Count of 0 = 10
# Count of 1 = 34
# Count of 2 = 41
# Current Entropy is = 1.399360
# Splitting on feature 3 with gain ratio 0.29650889567138455
# Level 3
# Count of 0 = 5
# Count of 1 = 0
# Count of 2 = 0
# Current Entropy is = -0.000000
# Reached leaf Node
# Level 3
# Count of 0 = 5
# Count of 1 = 34
# Count of 2 = 41
# Current Entropy is = 1.268890
# Splitting on feature 3 with gain ratio 0.2668047252230158
# Level 4
# Count of 0 = 3
# Count of 1 = 0
# Count of 2 = 0
# Current Entropy is = -0.000000
# Reached leaf Node
# Level 4
# Count of 0 = 2
# Count of 1 = 34
# Count of 2 = 41
# Current Entropy is = 1.141678
# Splitting on feature 3 with gain ratio 0.23735134328950394
# Level 5
# Count of 0 = 1
# Count of 1 = 0
# Count of 2 = 0
# Current Entropy is = -0.000000
# Reached leaf Node
# Level 5
# Count of 0 = 1
# Count of 1 = 34
# Count of 2 = 41
# Current Entropy is = 1.081699
# Splitting on feature 3 with gain ratio 0.22385492426003284
# Level 6
# Count of 0 = 1
# Count of 1 = 0
# Count of 2 = 0
# Current Entropy is = -0.000000
# Reached leaf Node
# Level 6
# Count of 0 = 0
# Count of 1 = 34
# Count of 2 = 41
# Current Entropy is = 0.993707
# Splitting on feature 3 with gain ratio 0.20250564798893203
# Level 7
# Count of 0 = 0
# Count of 1 = 7
# Count of 2 = 0
# Current Entropy is = -0.000000
# Reached leaf Node
# Level 7
# Count of 0 = 0
# Count of 1 = 27
# Count of 2 = 41
# Current Entropy is = 0.969204
# Splitting on feature 3 with gain ratio 0.19507498758804934
# Level 8
# Count of 0 = 0
# Count of 1 = 1
# Count of 2 = 0
# Current Entropy is = -0.000000
# Reached leaf Node
# Level 8
# Count of 0 = 0
# Count of 1 = 26
# Count of 2 = 41
# Current Entropy is = 0.963536
# Splitting on feature 3 with gain ratio 0.1955700232986793
# Level 9
# Count of 0 = 0
# Count of 1 = 2
# Count of 2 = 0
# Current Entropy is = -0.000000
# Reached leaf Node
# Level 9
# Count of 0 = 0
# Count of 1 = 24
# Count of 2 = 41
# Current Entropy is = 0.950080
# Splitting on feature 3 with gain ratio 0.1943959044255945
# Level 10
# Count of 0 = 0
# Count of 1 = 10
# Count of 2 = 0
# Current Entropy is = -0.000000
# Reached leaf Node
# Level 10
# Count of 0 = 0
# Count of 1 = 14
# Count of 2 = 41
# Current Entropy is = 0.818403
# Splitting on feature 3 with gain ratio 0.1461788856143589
# Level 11
# Count of 0 = 0
# Count of 1 = 5
# Count of 2 = 1
# Current Entropy is = 0.650022
# Splitting on feature 2 with gain ratio 0.2886898211584562
# Level 12
# Count of 0 = 0
# Count of 1 = 1
# Count of 2 = 0
# Current Entropy is = -0.000000
# Reached leaf Node
# Level 12
# Count of 0 = 0
# Count of 1 = 4
# Count of 2 = 1
# Current Entropy is = 0.721928
# Splitting on feature 2 with gain ratio 0.37562700540556493
# Level 13
# Count of 0 = 0
# Count of 1 = 1
# Count of 2 = 0
# Current Entropy is = -0.000000
# Reached leaf Node
# Level 13
# Count of 0 = 0
# Count of 1 = 3
# Count of 2 = 1
# Current Entropy is = 0.811278
# Splitting on feature 2 with gain ratio 0.5408520829727552
# Level 14
# Count of 0 = 0
# Count of 1 = 2
# Count of 2 = 0
# Current Entropy is = -0.000000
# Reached leaf Node
# Level 14
# Count of 0 = 0
# Count of 1 = 1
# Count of 2 = 1
# Current Entropy is = 1.000000
# Splitting on feature 0 with gain ratio 1.0
# Level 15
# Count of 0 = 0
# Count of 1 = 0
# Count of 2 = 1
# Current Entropy is = -0.000000
# Reached leaf Node
# Level 15
# Count of 0 = 0
# Count of 1 = 1
# Count of 2 = 0
# Current Entropy is = -0.000000
# Reached leaf Node
# Level 11
# Count of 0 = 0
# Count of 1 = 9
# Count of 2 = 40
# Current Entropy is = 0.688048
# Splitting on feature 3 with gain ratio 0.12459937206447125
# Level 12
# Count of 0 = 0
# Count of 1 = 6
# Count of 2 = 2
# Current Entropy is = 0.811278
# Splitting on feature 2 with gain ratio 0.2950102270760483
# Level 13
# Count of 0 = 0
# Count of 1 = 1
# Count of 2 = 0
# Current Entropy is = -0.000000
# Reached leaf Node
# Level 13
# Count of 0 = 0
# Count of 1 = 5
# Count of 2 = 2
# Current Entropy is = 0.863121
# Splitting on feature 2 with gain ratio 0.342285318584594
# Level 14
# Count of 0 = 0
# Count of 1 = 1
# Count of 2 = 0
# Current Entropy is = -0.000000
# Reached leaf Node
# Level 14
# Count of 0 = 0
# Count of 1 = 4
# Count of 2 = 2
# Current Entropy is = 0.918296
# Splitting on feature 2 with gain ratio 0.40783617806826955
# Level 15
# Count of 0 = 0
# Count of 1 = 1
# Count of 2 = 0
# Current Entropy is = -0.000000
# Reached leaf Node
# Level 15
# Count of 0 = 0
# Count of 1 = 3
# Count of 2 = 2
# Current Entropy is = 0.970951
# Splitting on feature 1 with gain ratio 0.5051961085524236
# Level 16
# Count of 0 = 0
# Count of 1 = 0
# Count of 2 = 1
# Current Entropy is = -0.000000
# Reached leaf Node
# Level 16
# Count of 0 = 0
# Count of 1 = 3
# Count of 2 = 1
# Current Entropy is = 0.811278
# Splitting on feature 1 with gain ratio 0.5408520829727552
# Level 17
# Count of 0 = 0
# Count of 1 = 1
# Count of 2 = 0
# Current Entropy is = -0.000000
# Reached leaf Node
# Level 17
# Count of 0 = 0
# Count of 1 = 2
# Count of 2 = 1
# Current Entropy is = 0.918296
# Splitting on feature 1 with gain ratio 1.0
# Level 18
# Count of 0 = 0
# Count of 1 = 0
# Count of 2 = 1
# Current Entropy is = -0.000000
# Reached leaf Node
# Level 18
# Count of 0 = 0
# Count of 1 = 2
# Count of 2 = 0
# Current Entropy is = -0.000000
# Reached leaf Node
# Level 12
# Count of 0 = 0
# Count of 1 = 3
# Count of 2 = 38
# Current Entropy is = 0.377646
# Splitting on feature 0 with gain ratio 0.06520358298196247
# Level 13
# Count of 0 = 0
# Count of 1 = 0
# Count of 2 = 1
# Current Entropy is = -0.000000
# Reached leaf Node
# Level 13
# Count of 0 = 0
# Count of 1 = 3
# Count of 2 = 37
# Current Entropy is = 0.384312
# Splitting on feature 0 with gain ratio 0.06730304576673662
# Level 14
# Count of 0 = 0
# Count of 1 = 0
# Count of 2 = 1
# Current Entropy is = -0.000000
# Reached leaf Node
# Level 14
# Count of 0 = 0
# Count of 1 = 3
# Count of 2 = 36
# Current Entropy is = 0.391244
# Splitting on feature 0 with gain ratio 0.06955514913467832
# Level 15
# Count of 0 = 0
# Count of 1 = 0
# Count of 2 = 1
# Current Entropy is = -0.000000
# Reached leaf Node
# Level 15
# Count of 0 = 0
# Count of 1 = 3
# Count of 2 = 35
# Current Entropy is = 0.398459
# Splitting on feature 0 with gain ratio 0.07197805399380959
# Level 16
# Count of 0 = 0
# Count of 1 = 0
# Count of 2 = 2
# Current Entropy is = -0.000000
# Reached leaf Node
# Level 16
# Count of 0 = 0
# Count of 1 = 3
# Count of 2 = 33
# Current Entropy is = 0.413817
# Splitting on feature 0 with gain ratio 0.07626075513395215
# Level 17
# Count of 0 = 0
# Count of 1 = 1
# Count of 2 = 1
# Current Entropy is = 1.000000
# Splitting on feature 1 with gain ratio 1.0
# Level 18
# Count of 0 = 0
# Count of 1 = 0
# Count of 2 = 1
# Current Entropy is = -0.000000
# Reached leaf Node
# Level 18
# Count of 0 = 0
# Count of 1 = 1
# Count of 2 = 0
# Current Entropy is = -0.000000
# Reached leaf Node
# Level 17
# Count of 0 = 0
# Count of 1 = 2
# Count of 2 = 32
# Current Entropy is = 0.322757
# Splitting on feature 3 with gain ratio 0.08072318668105517
# Level 18
# Count of 0 = 0
# Count of 1 = 2
# Count of 2 = 1
# Current Entropy is = 0.918296
# Splitting on feature 0 with gain ratio 1.0
# Level 19
# Count of 0 = 0
# Count of 1 = 2
# Count of 2 = 0
# Current Entropy is = -0.000000
# Reached leaf Node
# Level 19
# Count of 0 = 0
# Count of 1 = 0
# Count of 2 = 1
# Current Entropy is = -0.000000
# Reached leaf Node
# Level 18
# Count of 0 = 0
# Count of 1 = 0
# Count of 2 = 31
# Current Entropy is = -0.000000
# Reached leaf Node
#
# Train Accuracy: 1.00
# Test Accuracy: 0.92

# %%
def visualize_tree(tree, feature_names, class_names, filename='tree.png'):
    dot_data = export_graphviz(tree, out_file=None, 
                               feature_names=feature_names,  
                               class_names=class_names,  
                               filled=True, rounded=True,  
                               special_characters=True)  
    graph = pydotplus.graph_from_dot_data(dot_data)
    graph.write_png(filename)

# %%
# Visualize the decision tree
visualize_tree(decision_tree, iris.feature_names, iris.target_names, filename='decision_tree.png')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[27], line 2
#       1 # Visualize the decision tree
# ----> 2 visualize_tree(decision_tree, iris.feature_names, iris.target_names, filename='decision_tree.png')
#
# Cell In[26], line 2, in visualize_tree(tree, feature_names, class_names, filename)
#       1 def visualize_tree(tree, feature_names, class_names, filename='tree.png'):
# ----> 2     dot_data = export_graphviz(tree, out_file=None,
#       3                                feature_names=feature_names,
#       4                                class_names=class_names,
#       5                                filled=True, rounded=True,
#       6                                special_characters=True)
#       7     graph = pydotplus.graph_from_dot_data(dot_data)
#       8     graph.write_png(filename)
#
# File /opt/anaconda3/lib/python3.11/site-packages/sklearn/tree/_export.py:859, in export_graphviz(decision_tree, out_file, max_depth, feature_names, class_names, label, filled, leaves_parallel, impurity, node_ids, proportion, rotate, rounded, special_characters, precision, fontname)
#     740 def export_graphviz(
#     741     decision_tree,
#     742     out_file=None,
#    (...)
#     757     fontname="helvetica",
#     758 ):
#     759     """Export a decision tree in DOT format.
#     760
#     761     This function generates a GraphViz representation of the decision tree,
#    (...)
#     856     'digraph Tree {...
#     857     """
# --> 859     check_is_fitted(decision_tree)
#     860     own_file = False
#     861     return_string = False
#
# File /opt/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:1376, in check_is_fitted(estimator, attributes, msg, all_or_any)
#    1370     msg = (
#    1371         "This %(name)s instance is not fitted yet. Call 'fit' with "
#    1372         "appropriate arguments before using this estimator."
#    1373     )
#    1375 if not hasattr(estimator, "fit"):
# -> 1376     raise TypeError("%s is not an estimator instance." % (estimator))
#    1378 if attributes is not None:
#    1379     if not isinstance(attributes, (list, tuple)):
#
# TypeError: <__main__.Node object at 0x13318dc10> is not an estimator instance.
