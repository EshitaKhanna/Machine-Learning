# %%
from sklearn import datasets
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.tree import export_graphviz

# %%
iris = datasets.load_iris()
X_train, X_test, Y_train, Y_test = train_test_split(iris.data, iris.target, random_state = 1)

# %%
clf = DecisionTreeClassifier()
clf.fit(X_train, Y_train)
# Out:
# DecisionTreeClassifier()

# %% [markdown]
# #### Visualising the data using Graphviz and Pydotplus

# %%
conda install pydotplus
# Out:
# Channels:
#  - defaults
# Platform: osx-arm64
# Collecting package metadata (repodata.json): done
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /opt/anaconda3
#
#   added / updated specs:
#     - pydotplus
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     archspec-0.2.3             |     pyhd3eb1b0_0          47 KB
#     ca-certificates-2024.3.11  |       hca03da5_0         128 KB
#     cairo-1.16.0               |       h302bd0f_5         1.0 MB
#     certifi-2024.6.2           |  py311hca03da5_0         162 KB
#     conda-24.5.0               |  py311hca03da5_0         1.2 MB
#     expat-2.6.2                |       h313beb8_0         150 KB
#     font-ttf-dejavu-sans-mono-2.37|       hd3eb1b0_0         335 KB
#     font-ttf-inconsolata-2.001 |       hcb22688_0          83 KB
#     font-ttf-source-code-pro-2.030|       hd3eb1b0_0         654 KB
#     font-ttf-ubuntu-0.83       |       h8b1ccd4_0         1.5 MB
#     fontconfig-2.14.1          |       hee714a5_2         254 KB
#     fonts-anaconda-1           |       h8fa9717_0           3 KB
#     fonts-conda-ecosystem-1    |       hd3eb1b0_0           5 KB
#     fribidi-1.0.10             |       h1a28f6b_0          60 KB
#     frozendict-2.4.2           |  py311hca03da5_0          38 KB
#     gdk-pixbuf-2.42.10         |       h80987f9_0         581 KB
#     graphite2-1.3.14           |       hc377ac9_1          75 KB
#     graphviz-2.50.0            |       hf331ead_1         2.4 MB
#     gts-0.7.6                  |       hde733a8_3         287 KB
#     harfbuzz-4.3.0             |       he9eebac_2         1.1 MB
#     libgd-2.3.3                |       h14f8a72_1         200 KB
#     librsvg-2.54.4             |       hb3bd4c3_3         6.5 MB
#     libtool-2.4.6              |    h313beb8_1009         422 KB
#     libwebp-1.3.2              |       ha3663a8_0          86 KB
#     nspr-4.35                  |       h313beb8_0         243 KB
#     nss-3.89.1                 |       h313beb8_0         1.8 MB
#     openssl-3.0.14             |       h80987f9_0         4.3 MB
#     pango-1.50.7               |       h7271ec9_0         402 KB
#     pixman-0.40.0              |       h1a28f6b_0         196 KB
#     poppler-22.12.0            |       h52f4003_3         1.6 MB
#     poppler-data-0.4.11        |       hca03da5_1         2.6 MB
#     pydotplus-2.0.2            |             py_3          23 KB
#     ------------------------------------------------------------
#                                            Total:        28.4 MB
#
# The following NEW packages will be INSTALLED:
#
#   cairo              pkgs/main/osx-arm64::cairo-1.16.0-h302bd0f_5
#   expat              pkgs/main/osx-arm64::expat-2.6.2-h313beb8_0
#   font-ttf-dejavu-s~ pkgs/main/noarch::font-ttf-dejavu-sans-mono-2.37-hd3eb1b0_0
#   font-ttf-inconsol~ pkgs/main/noarch::font-ttf-inconsolata-2.001-hcb22688_0
#   font-ttf-source-c~ pkgs/main/noarch::font-ttf-source-code-pro-2.030-hd3eb1b0_0
#   font-ttf-ubuntu    pkgs/main/noarch::font-ttf-ubuntu-0.83-h8b1ccd4_0
#   fontconfig         pkgs/main/osx-arm64::fontconfig-2.14.1-hee714a5_2
#   fonts-anaconda     pkgs/main/noarch::fonts-anaconda-1-h8fa9717_0
#   fonts-conda-ecosy~ pkgs/main/noarch::fonts-conda-ecosystem-1-hd3eb1b0_0
#   fribidi            pkgs/main/osx-arm64::fribidi-1.0.10-h1a28f6b_0
#   frozendict         pkgs/main/osx-arm64::frozendict-2.4.2-py311hca03da5_0
#   gdk-pixbuf         pkgs/main/osx-arm64::gdk-pixbuf-2.42.10-h80987f9_0
#   graphite2          pkgs/main/osx-arm64::graphite2-1.3.14-hc377ac9_1
#   graphviz           pkgs/main/osx-arm64::graphviz-2.50.0-hf331ead_1
#   gts                pkgs/main/osx-arm64::gts-0.7.6-hde733a8_3
#   harfbuzz           pkgs/main/osx-arm64::harfbuzz-4.3.0-he9eebac_2
#   libgd              pkgs/main/osx-arm64::libgd-2.3.3-h14f8a72_1
#   librsvg            pkgs/main/osx-arm64::librsvg-2.54.4-hb3bd4c3_3
#   libtool            pkgs/main/osx-arm64::libtool-2.4.6-h313beb8_1009
#   libwebp            pkgs/main/osx-arm64::libwebp-1.3.2-ha3663a8_0
#   nspr               pkgs/main/osx-arm64::nspr-4.35-h313beb8_0
#   nss                pkgs/main/osx-arm64::nss-3.89.1-h313beb8_0
#   pango              pkgs/main/osx-arm64::pango-1.50.7-h7271ec9_0
#   pixman             pkgs/main/osx-arm64::pixman-0.40.0-h1a28f6b_0
#   poppler            pkgs/main/osx-arm64::poppler-22.12.0-h52f4003_3
#   poppler-data       pkgs/main/osx-arm64::poppler-data-0.4.11-hca03da5_1
#   pydotplus          pkgs/main/noarch::pydotplus-2.0.2-py_3
#
# The following packages will be UPDATED:
#
#   archspec                               0.2.1-pyhd3eb1b0_0 --> 0.2.3-pyhd3eb1b0_0
#   ca-certificates                     2023.12.12-hca03da5_0 --> 2024.3.11-hca03da5_0
#   certifi                          2024.2.2-py311hca03da5_0 --> 2024.6.2-py311hca03da5_0
#   conda                              24.1.2-py311hca03da5_0 --> 24.5.0-py311hca03da5_0
#   openssl                                 3.0.13-h1a28f6b_0 --> 3.0.14-h80987f9_0
#
#
#
# Downloading and Extracting Packages:
# librsvg-2.54.4       | 6.5 MB    |                                       |   0%
# openssl-3.0.14       | 4.3 MB    |                                       |   0%
#
# poppler-data-0.4.11  | 2.6 MB    |                                       |   0%
#
#
# graphviz-2.50.0      | 2.4 MB    |                                       |   0%
#
#
#
# nss-3.89.1           | 1.8 MB    |                                       |   0%
#
#
#
#
# poppler-22.12.0      | 1.6 MB    |                                       |   0%
#
#
#
#
#
# font-ttf-ubuntu-0.83 | 1.5 MB    |                                       |   0%
#
#
#
#
#
#
# conda-24.5.0         | 1.2 MB    |                                       |   0%
#
#
#
#
#
#
#
# harfbuzz-4.3.0       | 1.1 MB    |                                       |   0%
#
#
#
#
#
#
#
#
# cairo-1.16.0         | 1.0 MB    |                                       |   0%
#
#
#
#
#
#
#
#
#
# font-ttf-source-code | 654 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
# gdk-pixbuf-2.42.10   | 581 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
# libtool-2.4.6        | 422 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
# pango-1.50.7         | 402 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
# font-ttf-dejavu-sans | 335 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# gts-0.7.6            | 287 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# fontconfig-2.14.1    | 254 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# nspr-4.35            | 243 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libgd-2.3.3          | 200 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pixman-0.40.0        | 196 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# certifi-2024.6.2     | 162 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# expat-2.6.2          | 150 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ca-certificates-2024 | 128 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
# nss-3.89.1           | 1.8 MB    | 3                                     |   1%
# openssl-3.0.14       | 4.3 MB    | 1                                     |   0%
#
#
#
# nss-3.89.1           | 1.8 MB    | 6                                     |   2%
#
#
#
# nss-3.89.1           | 1.8 MB    | 9                                     |   3%
#
#
#
# nss-3.89.1           | 1.8 MB    | #2                                    |   3%
#
#
#
# nss-3.89.1           | 1.8 MB    | #5                                    |   4%
#
#
#
# nss-3.89.1           | 1.8 MB    | ##1                                   |   6%
#
# librsvg-2.54.4       | 6.5 MB    |                                       |   0%
# openssl-3.0.14       | 4.3 MB    | 3                                     |   1%
#
#
#
# nss-3.89.1           | 1.8 MB    | ###7                                  |  10%
#
#
#
# nss-3.89.1           | 1.8 MB    | ####3                                 |  12%
# openssl-3.0.14       | 4.3 MB    | 6                                     |   2%
#
#
# graphviz-2.50.0      | 2.4 MB    | 2                                     |   1%
# librsvg-2.54.4       | 6.5 MB    | 1                                     |   0%
# openssl-3.0.14       | 4.3 MB    | #                                     |   3%
#
#
#
# nss-3.89.1           | 1.8 MB    | #####                                 |  14%
# librsvg-2.54.4       | 6.5 MB    | 5                                     |   1%
#
# poppler-data-0.4.11  | 2.6 MB    | 4                                     |   1%
#
#
# graphviz-2.50.0      | 2.4 MB    | 4                                     |   1%
#
#
#
# nss-3.89.1           | 1.8 MB    | #####9                                |  16%
# librsvg-2.54.4       | 6.5 MB    | 8                                     |   2%
#
#
#
# nss-3.89.1           | 1.8 MB    | ######2                               |  17%
#
#
# graphviz-2.50.0      | 2.4 MB    | 7                                     |   2%
#
#
#
# nss-3.89.1           | 1.8 MB    | ######5                               |  18%
# openssl-3.0.14       | 4.3 MB    | #4                                    |   4%
#
#
#
# nss-3.89.1           | 1.8 MB    | ######9                               |  19%
#
# poppler-data-0.4.11  | 2.6 MB    | 6                                     |   2%
# openssl-3.0.14       | 4.3 MB    | #5                                    |   4%
#
#
# graphviz-2.50.0      | 2.4 MB    | 9                                     |   3%
#
#
#
# nss-3.89.1           | 1.8 MB    | #######2                              |  20%
# openssl-3.0.14       | 4.3 MB    | #7                                    |   5%
#
#
# graphviz-2.50.0      | 2.4 MB    | #2                                    |   3%
#
# librsvg-2.54.4       | 6.5 MB    | 8                                     |   2%
#
#
#
# librsvg-2.54.4       | 6.5 MB    | 9                                     |   3%
#
#
#
# nss-3.89.1           | 1.8 MB    | ########1                             |  22%
#
# poppler-data-0.4.11  | 2.6 MB    | #1                                    |   3%
# openssl-3.0.14       | 4.3 MB    | #8                                    |   5%
#
#
# librsvg-2.54.4       | 6.5 MB    | #                                     |   3%
#
#
# graphviz-2.50.0      | 2.4 MB    | #7                                    |   5%
#
#
#
# nss-3.89.1           | 1.8 MB    | ########7                             |  24%
#
# poppler-data-0.4.11  | 2.6 MB    | #3                                    |   4%
#
#
#
# librsvg-2.54.4       | 6.5 MB    | #1                                    |   3%
#
# poppler-data-0.4.11  | 2.6 MB    | #5                                    |   4%
#
#
# graphviz-2.50.0      | 2.4 MB    | #9                                    |   5%
# openssl-3.0.14       | 4.3 MB    | #9                                    |   5%
#
#
#
# nss-3.89.1           | 1.8 MB    | #########4                            |  25%
#
#
# graphviz-2.50.0      | 2.4 MB    | ##1                                   |   6%
#
#
#
# nss-3.89.1           | 1.8 MB    | #########7                            |  26%
#
# poppler-data-0.4.11  | 2.6 MB    | #7                                    |   5%
#
#
#
# nss-3.89.1           | 1.8 MB    | ##########3                           |  28%
#
#
#
# nss-3.89.1           | 1.8 MB    | ##########6                           |  29%
#
#
# graphviz-2.50.0      | 2.4 MB    | ##4                                   |   7%
# openssl-3.0.14       | 4.3 MB    | ##1                                   |   6%
#
# poppler-data-0.4.11  | 2.6 MB    | ##                                    |   5%
#
#
#
# nss-3.89.1           | 1.8 MB    | ###########6                          |  31%
#
#
# graphviz-2.50.0      | 2.4 MB    | ##9                                   |   8%
#
# poppler-data-0.4.11  | 2.6 MB    | ##2                                   |   6%
# openssl-3.0.14       | 4.3 MB    | ##3                                   |   6%
#
#
#
# nss-3.89.1           | 1.8 MB    | ############2                         |  33%
#
# poppler-data-0.4.11  | 2.6 MB    | ##4                                   |   7%
# openssl-3.0.14       | 4.3 MB    | ##5                                   |   7%
#
#
#
# librsvg-2.54.4       | 6.5 MB    | #2                                    |   3%
#
#
# graphviz-2.50.0      | 2.4 MB    | ###1                                  |   9%
#
#
#
# nss-3.89.1           | 1.8 MB    | #############4                        |  36%
# openssl-3.0.14       | 4.3 MB    | ##6                                   |   7%
#
# poppler-data-0.4.11  | 2.6 MB    | ##6                                   |   7%
#
#
# graphviz-2.50.0      | 2.4 MB    | ###6                                  |  10%
#
#
#
# nss-3.89.1           | 1.8 MB    | ##############4                       |  39%
#
# poppler-data-0.4.11  | 2.6 MB    | ##9                                   |   8%
# openssl-3.0.14       | 4.3 MB    | ##7                                   |   8%
#
#
# graphviz-2.50.0      | 2.4 MB    | ###8                                  |  11%
#
#
#
# nss-3.89.1           | 1.8 MB    | ###############                       |  41%
# librsvg-2.54.4       | 6.5 MB    | #3                                    |   4%
#
#
#
# librsvg-2.54.4       | 6.5 MB    | #5                                    |   4%
#
#
#
# nss-3.89.1           | 1.8 MB    | ################3                     |  44%
#
#
# librsvg-2.54.4       | 6.5 MB    | #6                                    |   5%
# openssl-3.0.14       | 4.3 MB    | ###                                   |   8%
#
#
# graphviz-2.50.0      | 2.4 MB    | ####6                                 |  12%
#
# poppler-data-0.4.11  | 2.6 MB    | ###1                                  |   8%
#
#
#
# nss-3.89.1           | 1.8 MB    | ################9                     |  46%
# openssl-3.0.14       | 4.3 MB    | ###1                                  |   9%
#
# poppler-data-0.4.11  | 2.6 MB    | ###3                                  |   9%
#
#
#
# nss-3.89.1           | 1.8 MB    | #################5                    |  48%
#
#
# librsvg-2.54.4       | 6.5 MB    | #8                                    |   5%
# librsvg-2.54.4       | 6.5 MB    | ##1                                   |   6%
#
# poppler-data-0.4.11  | 2.6 MB    | ###5                                  |  10%
#
#
# graphviz-2.50.0      | 2.4 MB    | #####3                                |  14%
#
#
#
# librsvg-2.54.4       | 6.5 MB    | ##4                                   |   6%
#
#
# graphviz-2.50.0      | 2.4 MB    | #####5                                |  15%
#
# poppler-data-0.4.11  | 2.6 MB    | ###8                                  |  10%
# librsvg-2.54.4       | 6.5 MB    | ##5                                   |   7%
#
#
#
# librsvg-2.54.4       | 6.5 MB    | ##7                                   |   7%
#
#
#
# nss-3.89.1           | 1.8 MB    | ###################4                  |  53%
# openssl-3.0.14       | 4.3 MB    | ###7                                  |  10%
#
#
# graphviz-2.50.0      | 2.4 MB    | ######                                |  16%
#
# poppler-data-0.4.11  | 2.6 MB    | ####                                  |  11%
#
#
# graphviz-2.50.0      | 2.4 MB    | ######3                               |  17%
# openssl-3.0.14       | 4.3 MB    | ###9                                  |  11%
#
#
#
# nss-3.89.1           | 1.8 MB    | ####################                  |  54%
#
# poppler-data-0.4.11  | 2.6 MB    | ####2                                 |  11%
# openssl-3.0.14       | 4.3 MB    | ####1                                 |  11%
#
#
#
# nss-3.89.1           | 1.8 MB    | ####################7                 |  56%
#
#
# graphviz-2.50.0      | 2.4 MB    | ######8                               |  18%
#
#
#
# librsvg-2.54.4       | 6.5 MB    | ###                                   |   8%
# openssl-3.0.14       | 4.3 MB    | ####3                                 |  12%
#
# poppler-data-0.4.11  | 2.6 MB    | ####4                                 |  12%
#
#
# graphviz-2.50.0      | 2.4 MB    | #######                               |  19%
#
#
#
# nss-3.89.1           | 1.8 MB    | ######################9               |  62%
# openssl-3.0.14       | 4.3 MB    | ####6                                 |  13%
#
# poppler-data-0.4.11  | 2.6 MB    | ####7                                 |  13%
#
#
#
# nss-3.89.1           | 1.8 MB    | #######################5              |  64%
# librsvg-2.54.4       | 6.5 MB    | ###6                                  |  10%
# openssl-3.0.14       | 4.3 MB    | ####9                                 |  13%
#
# poppler-data-0.4.11  | 2.6 MB    | ####9                                 |  13%
#
#
#
# nss-3.89.1           | 1.8 MB    | ########################1             |  65%
#
#
# graphviz-2.50.0      | 2.4 MB    | #######5                              |  20%
#
#
#
# librsvg-2.54.4       | 6.5 MB    | ###8                                  |  10%
#
#
# graphviz-2.50.0      | 2.4 MB    | #######7                              |  21%
# librsvg-2.54.4       | 6.5 MB    | ####1                                 |  11%
#
# poppler-data-0.4.11  | 2.6 MB    | #####1                                |  14%
#
#
#
# librsvg-2.54.4       | 6.5 MB    | ####4                                 |  12%
# openssl-3.0.14       | 4.3 MB    | #####7                                |  15%
#
#
#
# nss-3.89.1           | 1.8 MB    | ##########################3           |  71%
#
#
# librsvg-2.54.4       | 6.5 MB    | ####8                                 |  13%
#
#
#
# nss-3.89.1           | 1.8 MB    | ##########################9           |  73%
# librsvg-2.54.4       | 6.5 MB    | #####3                                |  14%
#
# poppler-data-0.4.11  | 2.6 MB    | #####3                                |  15%
# openssl-3.0.14       | 4.3 MB    | ######3                               |  17%
#
#
# graphviz-2.50.0      | 2.4 MB    | ########2                             |  22%
#
#
#
# nss-3.89.1           | 1.8 MB    | ###########################6          |  75%
# librsvg-2.54.4       | 6.5 MB    | #####9                                |  16%
# openssl-3.0.14       | 4.3 MB    | ######9                               |  19%
#
#
#
# nss-3.89.1           | 1.8 MB    | ############################8         |  78%
#
#
# graphviz-2.50.0      | 2.4 MB    | ########5                             |  23%
#
# poppler-data-0.4.11  | 2.6 MB    | #####8                                |  16%
#
#
#
# nss-3.89.1           | 1.8 MB    | ##############################1       |  81%
# librsvg-2.54.4       | 6.5 MB    | ######8                               |  18%
#
#
#
# nss-3.89.1           | 1.8 MB    | ##############################7       |  83%
#
# librsvg-2.54.4       | 6.5 MB    | #######3                              |  20%
# openssl-3.0.14       | 4.3 MB    | #######4                              |  20%
#
#
# graphviz-2.50.0      | 2.4 MB    | #########                             |  24%
#
#
#
# nss-3.89.1           | 1.8 MB    | ###############################3      |  85%
#
# librsvg-2.54.4       | 6.5 MB    | #######8                              |  21%
# openssl-3.0.14       | 4.3 MB    | #######8                              |  21%
#
#
# graphviz-2.50.0      | 2.4 MB    | #########2                            |  25%
#
#
#
# librsvg-2.54.4       | 6.5 MB    | ########1                             |  22%
# openssl-3.0.14       | 4.3 MB    | ########1                             |  22%
#
#
# graphviz-2.50.0      | 2.4 MB    | #########4                            |  26%
#
# poppler-data-0.4.11  | 2.6 MB    | ######4                               |  18%
#
#
#
# librsvg-2.54.4       | 6.5 MB    | ########5                             |  23%
#
#
# librsvg-2.54.4       | 6.5 MB    | #########4                            |  25%
#
# poppler-data-0.4.11  | 2.6 MB    | ######7                               |  18%
# openssl-3.0.14       | 4.3 MB    | ########5                             |  23%
# openssl-3.0.14       | 4.3 MB    | ########7                             |  24%
#
#
# graphviz-2.50.0      | 2.4 MB    | #########9                            |  27%
#
#
#
# nss-3.89.1           | 1.8 MB    | ##################################2   |  92%
#
# poppler-data-0.4.11  | 2.6 MB    | ######9                               |  19%
#
#
# graphviz-2.50.0      | 2.4 MB    | ##########2                           |  28%
# librsvg-2.54.4       | 6.5 MB    | #########7                            |  26%
#
#
#
# nss-3.89.1           | 1.8 MB    | ##################################### | 100%
#
#
#
# nss-3.89.1           | 1.8 MB    | ##################################### | 100%
# librsvg-2.54.4       | 6.5 MB    | ##########                            |  27%
#
#
# graphviz-2.50.0      | 2.4 MB    | ##########7                           |  29%
#
# poppler-data-0.4.11  | 2.6 MB    | #######3                              |  20%
#
#
#
#
# poppler-22.12.0      | 1.6 MB    | 3                                     |   1%
# librsvg-2.54.4       | 6.5 MB    | ##########7                           |  29%
# openssl-3.0.14       | 4.3 MB    | ##########2                           |  28%
#
#
#
#
# poppler-22.12.0      | 1.6 MB    | ##2                                   |   6%
# librsvg-2.54.4       | 6.5 MB    | ###########1                          |  30%
#
# poppler-data-0.4.11  | 2.6 MB    | #######6                              |  21%
#
#
#
#
# poppler-22.12.0      | 1.6 MB    | ###3                                  |   9%
#
#
# graphviz-2.50.0      | 2.4 MB    | ###########1                          |  30%
#
# librsvg-2.54.4       | 6.5 MB    | ###########3                          |  31%
#
#
# graphviz-2.50.0      | 2.4 MB    | ###########4                          |  31%
# openssl-3.0.14       | 4.3 MB    | ##########7                           |  29%
#
#
#
#
# librsvg-2.54.4       | 6.5 MB    | ############                          |  33%
#
#
#
#
# poppler-22.12.0      | 1.6 MB    | #####5                                |  15%
# openssl-3.0.14       | 4.3 MB    | ###########1                          |  30%
#
# poppler-data-0.4.11  | 2.6 MB    | ########                              |  22%
#
#
# librsvg-2.54.4       | 6.5 MB    | ############5                         |  34%
#
#
#
#
# poppler-22.12.0      | 1.6 MB    | #######                               |  19%
# openssl-3.0.14       | 4.3 MB    | ###########8                          |  32%
#
#
# graphviz-2.50.0      | 2.4 MB    | ############1                         |  33%
#
# librsvg-2.54.4       | 6.5 MB    | ############8                         |  35%
# openssl-3.0.14       | 4.3 MB    | ############2                         |  33%
#
#
# graphviz-2.50.0      | 2.4 MB    | ############4                         |  34%
#
#
#
#
# poppler-22.12.0      | 1.6 MB    | ########1                             |  22%
# openssl-3.0.14       | 4.3 MB    | ############6                         |  34%
#
# poppler-data-0.4.11  | 2.6 MB    | ########5                             |  23%
#
#
# graphviz-2.50.0      | 2.4 MB    | ############8                         |  35%
# openssl-3.0.14       | 4.3 MB    | #############                         |  35%
#
#
#
#
# poppler-22.12.0      | 1.6 MB    | #########2                            |  25%
#
#
# graphviz-2.50.0      | 2.4 MB    | #############1                        |  36%
#
#
# graphviz-2.50.0      | 2.4 MB    | #############8                        |  37%
# openssl-3.0.14       | 4.3 MB    | #############3                        |  36%
#
# poppler-data-0.4.11  | 2.6 MB    | ########7                             |  24%
#
#
#
#
# poppler-22.12.0      | 1.6 MB    | #########9                            |  27%
# openssl-3.0.14       | 4.3 MB    | #############5                        |  37%
#
#
#
#
# poppler-22.12.0      | 1.6 MB    | ##########7                           |  29%
# openssl-3.0.14       | 4.3 MB    | #############9                        |  38%
#
#
# graphviz-2.50.0      | 2.4 MB    | ##############3                       |  39%
# openssl-3.0.14       | 4.3 MB    | ##############2                       |  39%
#
#
#
#
# poppler-22.12.0      | 1.6 MB    | ###########4                          |  31%
#
# poppler-data-0.4.11  | 2.6 MB    | #########1                            |  25%
#
#
#
#
# poppler-22.12.0      | 1.6 MB    | ############5                         |  34%
# openssl-3.0.14       | 4.3 MB    | ###############                       |  41%
#
# poppler-data-0.4.11  | 2.6 MB    | #########4                            |  25%
#
#
#
#
# poppler-22.12.0      | 1.6 MB    | ##############                        |  38%
#
#
# graphviz-2.50.0      | 2.4 MB    | ###############                       |  41%
# openssl-3.0.14       | 4.3 MB    | ###############4                      |  42%
#
#
# graphviz-2.50.0      | 2.4 MB    | ###############3                      |  41%
#
#
#
#
# poppler-22.12.0      | 1.6 MB    | ##############7                       |  40%
# openssl-3.0.14       | 4.3 MB    | ###############7                      |  42%
#
#
# graphviz-2.50.0      | 2.4 MB    | ###############5                      |  42%
#
#
#
#
# poppler-22.12.0      | 1.6 MB    | ###############5                      |  42%
# openssl-3.0.14       | 4.3 MB    | ###############9                      |  43%
#
# poppler-data-0.4.11  | 2.6 MB    | #########6                            |  26%
#
#
#
#
# poppler-22.12.0      | 1.6 MB    | ################2                     |  44%
#
#
# graphviz-2.50.0      | 2.4 MB    | ###############8                      |  43%
# openssl-3.0.14       | 4.3 MB    | #################                     |  46%
#
#
# graphviz-2.50.0      | 2.4 MB    | ################2                     |  44%
#
#
#
#
# poppler-22.12.0      | 1.6 MB    | #################7                    |  48%
# openssl-3.0.14       | 4.3 MB    | #################5                    |  48%
#
# poppler-data-0.4.11  | 2.6 MB    | ##########                            |  27%
#
#
# librsvg-2.54.4       | 6.5 MB    | #############1                        |  36%
#
#
#
#
# poppler-22.12.0      | 1.6 MB    | ###################2                  |  52%
# librsvg-2.54.4       | 6.5 MB    | #############9                        |  38%
#
#
# graphviz-2.50.0      | 2.4 MB    | #################                     |  46%
#
# poppler-data-0.4.11  | 2.6 MB    | ##########2                           |  28%
#
#
#
#
# poppler-22.12.0      | 1.6 MB    | ###################9                  |  54%
# openssl-3.0.14       | 4.3 MB    | ##################3                   |  50%
#
#
#
#
# poppler-22.12.0      | 1.6 MB    | ####################7                 |  56%
# librsvg-2.54.4       | 6.5 MB    | ##############2                       |  38%
#
#
#
#
# poppler-22.12.0      | 1.6 MB    | #####################4                |  58%
#
#
# graphviz-2.50.0      | 2.4 MB    | #################5                    |  47%
#
# poppler-data-0.4.11  | 2.6 MB    | ##########5                           |  28%
# librsvg-2.54.4       | 6.5 MB    | ##############9                       |  40%
# openssl-3.0.14       | 4.3 MB    | ###################3                  |  52%
#
#
# graphviz-2.50.0      | 2.4 MB    | #################7                    |  48%
#
#
#
#
# poppler-22.12.0      | 1.6 MB    | ######################1               |  60%
#
# poppler-data-0.4.11  | 2.6 MB    | ##########7                           |  29%
# openssl-3.0.14       | 4.3 MB    | ###################7                  |  53%
#
#
#
#
# poppler-22.12.0      | 1.6 MB    | #######################2              |  63%
#
#
# graphviz-2.50.0      | 2.4 MB    | ##################2                   |  49%
#
#
#
#
# librsvg-2.54.4       | 6.5 MB    | ###############2                      |  41%
#
#
# graphviz-2.50.0      | 2.4 MB    | ##################4                   |  50%
#
# poppler-data-0.4.11  | 2.6 MB    | ##########9                           |  30%
# librsvg-2.54.4       | 6.5 MB    | ###############4                      |  42%
#
# poppler-data-0.4.11  | 2.6 MB    | ###########1                          |  30%
#
#
#
#
# poppler-22.12.0      | 1.6 MB    | ########################7             |  67%
# openssl-3.0.14       | 4.3 MB    | ####################6                 |  56%
#
#
# graphviz-2.50.0      | 2.4 MB    | ##################7                   |  51%
#
# librsvg-2.54.4       | 6.5 MB    | ###############6                      |  42%
#
#
#
#
# poppler-22.12.0      | 1.6 MB    | #########################8            |  70%
# openssl-3.0.14       | 4.3 MB    | #####################3                |  58%
#
#
# graphviz-2.50.0      | 2.4 MB    | ###################4                  |  53%
#
#
#
#
# librsvg-2.54.4       | 6.5 MB    | ###############8                      |  43%
#
# poppler-data-0.4.11  | 2.6 MB    | ###########6                          |  31%
#
#
# graphviz-2.50.0      | 2.4 MB    | ###################9                  |  54%
# openssl-3.0.14       | 4.3 MB    | #####################4                |  58%
#
#
#
#
# librsvg-2.54.4       | 6.5 MB    | ###############9                      |  43%
#
#
#
#
# librsvg-2.54.4       | 6.5 MB    | ################                      |  43%
#
#
#
#
# poppler-22.12.0      | 1.6 MB    | ###########################3          |  74%
#
#
# librsvg-2.54.4       | 6.5 MB    | ################1                     |  44%
#
# librsvg-2.54.4       | 6.5 MB    | ################3                     |  44%
# openssl-3.0.14       | 4.3 MB    | #####################7                |  59%
#
#
# graphviz-2.50.0      | 2.4 MB    | ####################6                 |  56%
# openssl-3.0.14       | 4.3 MB    | #####################8                |  59%
#
#
#
#
# poppler-22.12.0      | 1.6 MB    | ###########################7          |  75%
# openssl-3.0.14       | 4.3 MB    | #####################9                |  59%
#
#
# librsvg-2.54.4       | 6.5 MB    | ################4                     |  44%
# openssl-3.0.14       | 4.3 MB    | ######################2               |  60%
#
#
# graphviz-2.50.0      | 2.4 MB    | #####################1                |  57%
#
# poppler-data-0.4.11  | 2.6 MB    | ############                          |  33%
#
#
# graphviz-2.50.0      | 2.4 MB    | #####################4                |  58%
#
#
#
#
# poppler-22.12.0      | 1.6 MB    | ############################1         |  76%
#
# librsvg-2.54.4       | 6.5 MB    | ################7                     |  45%
#
#
# graphviz-2.50.0      | 2.4 MB    | #####################6                |  59%
#
#
#
#
# poppler-22.12.0      | 1.6 MB    | ############################4         |  77%
#
# poppler-data-0.4.11  | 2.6 MB    | ############5                         |  34%
# librsvg-2.54.4       | 6.5 MB    | ################9                     |  46%
# openssl-3.0.14       | 4.3 MB    | #######################8              |  64%
#
#
# graphviz-2.50.0      | 2.4 MB    | ######################1               |  60%
#
# librsvg-2.54.4       | 6.5 MB    | #################1                    |  46%
#
#
#
#
# poppler-22.12.0      | 1.6 MB    | ############################8         |  78%
# openssl-3.0.14       | 4.3 MB    | ########################3             |  66%
#
#
# librsvg-2.54.4       | 6.5 MB    | #################3                    |  47%
# openssl-3.0.14       | 4.3 MB    | ########################7             |  67%
#
# poppler-data-0.4.11  | 2.6 MB    | ############9                         |  35%
#
#
# graphviz-2.50.0      | 2.4 MB    | ######################8               |  62%
# openssl-3.0.14       | 4.3 MB    | #########################             |  68%
#
#
#
#
# librsvg-2.54.4       | 6.5 MB    | #################5                    |  47%
#
#
# graphviz-2.50.0      | 2.4 MB    | #######################1              |  62%
# librsvg-2.54.4       | 6.5 MB    | #################7                    |  48%
# openssl-3.0.14       | 4.3 MB    | #########################5            |  69%
#
# poppler-data-0.4.11  | 2.6 MB    | #############2                        |  36%
#
#
#
#
# poppler-22.12.0      | 1.6 MB    | #############################5        |  80%
#
#
# librsvg-2.54.4       | 6.5 MB    | ##################1                   |  49%
# openssl-3.0.14       | 4.3 MB    | ##########################1           |  71%
#
# poppler-data-0.4.11  | 2.6 MB    | #############6                        |  37%
#
#
# librsvg-2.54.4       | 6.5 MB    | ##################4                   |  50%
#
#
#
#
# poppler-22.12.0      | 1.6 MB    | #############################9        |  81%
# librsvg-2.54.4       | 6.5 MB    | ##################6                   |  50%
#
# poppler-data-0.4.11  | 2.6 MB    | #############8                        |  38%
# openssl-3.0.14       | 4.3 MB    | ###########################           |  73%
#
#
# librsvg-2.54.4       | 6.5 MB    | ##################9                   |  51%
# openssl-3.0.14       | 4.3 MB    | ###########################4          |  74%
#
#
#
#
# poppler-22.12.0      | 1.6 MB    | ##############################3       |  82%
#
#
# librsvg-2.54.4       | 6.5 MB    | ###################2                  |  52%
#
# poppler-data-0.4.11  | 2.6 MB    | ##############1                       |  38%
# librsvg-2.54.4       | 6.5 MB    | ###################9                  |  54%
# openssl-3.0.14       | 4.3 MB    | ############################1         |  76%
#
#
# graphviz-2.50.0      | 2.4 MB    | ########################5             |  66%
#
# poppler-data-0.4.11  | 2.6 MB    | ##############3                       |  39%
#
#
#
#
# poppler-22.12.0      | 1.6 MB    | ##############################6       |  83%
# librsvg-2.54.4       | 6.5 MB    | ####################1                 |  55%
#
#
# graphviz-2.50.0      | 2.4 MB    | ########################8             |  67%
# openssl-3.0.14       | 4.3 MB    | ############################7         |  78%
#
# librsvg-2.54.4       | 6.5 MB    | ####################7                 |  56%
#
#
#
#
# poppler-22.12.0      | 1.6 MB    | ###############################       |  84%
#
#
# graphviz-2.50.0      | 2.4 MB    | #########################             |  68%
# openssl-3.0.14       | 4.3 MB    | #############################         |  78%
#
# poppler-data-0.4.11  | 2.6 MB    | ##############7                       |  40%
# openssl-3.0.14       | 4.3 MB    | #############################4        |  80%
#
#
#
#
# poppler-22.12.0      | 1.6 MB    | ###############################4      |  85%
#
#
# librsvg-2.54.4       | 6.5 MB    | ####################9                 |  57%
#
# poppler-data-0.4.11  | 2.6 MB    | ##############9                       |  41%
# librsvg-2.54.4       | 6.5 MB    | #####################6                |  58%
#
#
# graphviz-2.50.0      | 2.4 MB    | #########################5            |  69%
# librsvg-2.54.4       | 6.5 MB    | #####################9                |  59%
#
# poppler-data-0.4.11  | 2.6 MB    | ###############2                      |  41%
#
#
#
#
# librsvg-2.54.4       | 6.5 MB    | ######################3               |  60%
# openssl-3.0.14       | 4.3 MB    | ##############################7       |  83%
#
#
# librsvg-2.54.4       | 6.5 MB    | ######################8               |  62%
# openssl-3.0.14       | 4.3 MB    | ###############################       |  84%
#
# poppler-data-0.4.11  | 2.6 MB    | ###############4                      |  42%
#
#
#
#
# poppler-22.12.0      | 1.6 MB    | ################################1     |  87%
# librsvg-2.54.4       | 6.5 MB    | #######################2              |  63%
#
#
# librsvg-2.54.4       | 6.5 MB    | #######################6              |  64%
# openssl-3.0.14       | 4.3 MB    | ###############################5      |  85%
#
# poppler-data-0.4.11  | 2.6 MB    | ###############6                      |  42%
# openssl-3.0.14       | 4.3 MB    | ###############################8      |  86%
#
#
#
#
# librsvg-2.54.4       | 6.5 MB    | ########################              |  65%
#
#
# graphviz-2.50.0      | 2.4 MB    | ##########################2           |  71%
# openssl-3.0.14       | 4.3 MB    | ################################1     |  87%
#
# librsvg-2.54.4       | 6.5 MB    | ########################3             |  66%
# librsvg-2.54.4       | 6.5 MB    | ########################6             |  67%
#
#
# graphviz-2.50.0      | 2.4 MB    | ##########################5           |  72%
#
# poppler-data-0.4.11  | 2.6 MB    | ################1                     |  44%
#
#
#
#
# poppler-22.12.0      | 1.6 MB    | ################################9     |  89%
# openssl-3.0.14       | 4.3 MB    | #################################     |  89%
#
#
# graphviz-2.50.0      | 2.4 MB    | ##########################7           |  72%
# librsvg-2.54.4       | 6.5 MB    | ########################8             |  67%
#
# poppler-data-0.4.11  | 2.6 MB    | ################3                     |  44%
#
#
#
#
# poppler-22.12.0      | 1.6 MB    | #################################2    |  90%
# librsvg-2.54.4       | 6.5 MB    | #########################5            |  69%
#
#
# graphviz-2.50.0      | 2.4 MB    | ###########################           |  73%
# openssl-3.0.14       | 4.3 MB    | #################################9    |  92%
#
#
#
#
# poppler-22.12.0      | 1.6 MB    | #################################6    |  91%
#
# librsvg-2.54.4       | 6.5 MB    | #########################8            |  70%
# openssl-3.0.14       | 4.3 MB    | ##################################2   |  93%
#
#
# librsvg-2.54.4       | 6.5 MB    | ##########################2           |  71%
# openssl-3.0.14       | 4.3 MB    | ##################################5   |  93%
#
# poppler-data-0.4.11  | 2.6 MB    | ################7                     |  45%
#
#
#
#
# poppler-22.12.0      | 1.6 MB    | ##################################    |  92%
# librsvg-2.54.4       | 6.5 MB    | ##########################4           |  72%
#
#
# graphviz-2.50.0      | 2.4 MB    | ###########################4          |  74%
#
# poppler-data-0.4.11  | 2.6 MB    | #################                     |  46%
# openssl-3.0.14       | 4.3 MB    | ###################################2  |  95%
#
#
#
#
# librsvg-2.54.4       | 6.5 MB    | ##########################7           |  72%
#
#
# librsvg-2.54.4       | 6.5 MB    | ###########################           |  73%
# openssl-3.0.14       | 4.3 MB    | ###################################6  |  96%
#
#
#
#
# poppler-22.12.0      | 1.6 MB    | ##################################7   |  94%
# openssl-3.0.14       | 4.3 MB    | ####################################  |  98%
#
#
# graphviz-2.50.0      | 2.4 MB    | ###########################9          |  76%
#
# librsvg-2.54.4       | 6.5 MB    | ###########################4          |  74%
#
#
#
#
# poppler-22.12.0      | 1.6 MB    | ###################################1  |  95%
#
# poppler-data-0.4.11  | 2.6 MB    | #################4                    |  47%
# librsvg-2.54.4       | 6.5 MB    | ###########################7          |  75%
#
#
# graphviz-2.50.0      | 2.4 MB    | ############################2         |  76%
# librsvg-2.54.4       | 6.5 MB    | ############################2         |  76%
#
# poppler-data-0.4.11  | 2.6 MB    | #################6                    |  48%
#
#
#
#
# poppler-22.12.0      | 1.6 MB    | ###################################5  |  96%
# librsvg-2.54.4       | 6.5 MB    | ############################8         |  78%
#
#
# graphviz-2.50.0      | 2.4 MB    | ############################4         |  77%
#
#
#
#
#
# librsvg-2.54.4       | 6.5 MB    | #############################1        |  79%
#
#
#
#
# poppler-22.12.0      | 1.6 MB    | ###################################8  |  97%
#
# poppler-data-0.4.11  | 2.6 MB    | #################9                    |  48%
#
#
#
#
#
# font-ttf-ubuntu-0.83 | 1.5 MB    | #1                                    |   3%
#
#
#
#
#
# font-ttf-ubuntu-0.83 | 1.5 MB    | #9                                    |   5%
#
#
# librsvg-2.54.4       | 6.5 MB    | #############################5        |  80%
#
#
#
#
# poppler-22.12.0      | 1.6 MB    | ####################################2 |  98%
#
#
#
#
#
# font-ttf-ubuntu-0.83 | 1.5 MB    | ##7                                   |   7%
#
# poppler-data-0.4.11  | 2.6 MB    | ##################1                   |  49%
#
#
#
#
#
# librsvg-2.54.4       | 6.5 MB    | ##############################        |  81%
#
#
# graphviz-2.50.0      | 2.4 MB    | ############################9         |  78%
#
#
#
#
# librsvg-2.54.4       | 6.5 MB    | ##############################3       |  82%
#
# poppler-data-0.4.11  | 2.6 MB    | ##################3                   |  50%
#
#
#
#
#
# font-ttf-ubuntu-0.83 | 1.5 MB    | ####2                                 |  12%
#
#
# librsvg-2.54.4       | 6.5 MB    | ##############################6       |  83%
#
#
#
#
# poppler-22.12.0      | 1.6 MB    | ##################################### | 100%
#
#
#
#
# poppler-22.12.0      | 1.6 MB    | ##################################### | 100%
#
#
#
#
#
# librsvg-2.54.4       | 6.5 MB    | ##############################9       |  84%
#
# poppler-data-0.4.11  | 2.6 MB    | ##################5                   |  50%
#
#
#
#
#
# librsvg-2.54.4       | 6.5 MB    | ###############################2      |  84%
#
#
#
#
#
# librsvg-2.54.4       | 6.5 MB    | ###############################4      |  85%
#
# poppler-data-0.4.11  | 2.6 MB    | ##################8                   |  51%
#
#
#
#
#
# font-ttf-ubuntu-0.83 | 1.5 MB    | ########1                             |  22%
#
#
#
#
#
#
# conda-24.5.0         | 1.2 MB    | 4                                     |   1%
#
#
# librsvg-2.54.4       | 6.5 MB    | ###############################8      |  86%
#
#
#
#
#
# font-ttf-ubuntu-0.83 | 1.5 MB    | #########2                            |  25%
#
# poppler-data-0.4.11  | 2.6 MB    | ###################                   |  51%
#
#
#
#
#
#
# librsvg-2.54.4       | 6.5 MB    | ################################4     |  88%
#
#
# graphviz-2.50.0      | 2.4 MB    | #############################9        |  81%
#
# librsvg-2.54.4       | 6.5 MB    | ################################8     |  89%
#
#
#
#
#
#
# conda-24.5.0         | 1.2 MB    | #3                                    |   4%
#
#
#
#
#
# font-ttf-ubuntu-0.83 | 1.5 MB    | ##########                            |  27%
#
#
# librsvg-2.54.4       | 6.5 MB    | #################################     |  89%
#
#
#
#
#
# font-ttf-ubuntu-0.83 | 1.5 MB    | ############3                         |  33%
#
#
#
#
#
#
# conda-24.5.0         | 1.2 MB    | #8                                    |   5%
#
# librsvg-2.54.4       | 6.5 MB    | #################################4    |  90%
#
#
# graphviz-2.50.0      | 2.4 MB    | ##############################4       |  82%
#
#
#
#
#
# font-ttf-ubuntu-0.83 | 1.5 MB    | #############5                        |  37%
#
#
#
#
#
#
# conda-24.5.0         | 1.2 MB    | ##3                                   |   6%
#
# librsvg-2.54.4       | 6.5 MB    | ##################################    |  92%
#
#
#
#
#
# font-ttf-ubuntu-0.83 | 1.5 MB    | ##############7                       |  40%
#
#
# librsvg-2.54.4       | 6.5 MB    | ##################################3   |  93%
#
#
#
#
#
#
# conda-24.5.0         | 1.2 MB    | ##7                                   |   8%
#
#
#
#
#
# font-ttf-ubuntu-0.83 | 1.5 MB    | ###############4                      |  42%
#
# poppler-data-0.4.11  | 2.6 MB    | ###################9                  |  54%
#
#
# graphviz-2.50.0      | 2.4 MB    | ##############################8       |  84%
#
#
#
#
#
#
# librsvg-2.54.4       | 6.5 MB    | ##################################5   |  93%
#
#
#
#
#
# font-ttf-ubuntu-0.83 | 1.5 MB    | ################6                     |  45%
#
#
#
#
#
#
# librsvg-2.54.4       | 6.5 MB    | ###################################2  |  95%
#
# poppler-data-0.4.11  | 2.6 MB    | ####################1                 |  54%
#
#
# librsvg-2.54.4       | 6.5 MB    | ###################################6  |  96%
#
#
#
#
#
#
# conda-24.5.0         | 1.2 MB    | ####1                                 |  11%
#
#
#
#
#
# librsvg-2.54.4       | 6.5 MB    | ####################################  |  97%
#
# poppler-data-0.4.11  | 2.6 MB    | ####################3                 |  55%
#
#
#
#
#
# font-ttf-ubuntu-0.83 | 1.5 MB    | ##################2                   |  49%
#
#
# librsvg-2.54.4       | 6.5 MB    | ####################################3 |  98%
#
#
#
#
#
#
# conda-24.5.0         | 1.2 MB    | ####6                                 |  13%
#
# poppler-data-0.4.11  | 2.6 MB    | ####################5                 |  56%
#
#
#
#
#
# font-ttf-ubuntu-0.83 | 1.5 MB    | ###################3                  |  52%
#
#
# graphviz-2.50.0      | 2.4 MB    | ###############################6      |  85%
#
#
#
#
#
#
# conda-24.5.0         | 1.2 MB    | #####1                                |  14%
#
#
#
#
#
# librsvg-2.54.4       | 6.5 MB    | ####################################7 |  99%
#
# poppler-data-0.4.11  | 2.6 MB    | ####################8                 |  56%
#
#
#
#
#
# font-ttf-ubuntu-0.83 | 1.5 MB    | ####################9                 |  57%
#
#
#
#
#
#
#
# librsvg-2.54.4       | 6.5 MB    | ##################################### | 100%
#
#
# graphviz-2.50.0      | 2.4 MB    | ###############################8      |  86%
#
#
#
#
#
#
# conda-24.5.0         | 1.2 MB    | #####5                                |  15%
#
#
#
#
#
# font-ttf-ubuntu-0.83 | 1.5 MB    | #####################6                |  59%
#
# poppler-data-0.4.11  | 2.6 MB    | #####################                 |  57%
#
#
#
#
#
#
#
# harfbuzz-4.3.0       | 1.1 MB    | ####1                                 |  11%
#
#
#
#
#
#
# conda-24.5.0         | 1.2 MB    | ######                                |  16%
#
#
# graphviz-2.50.0      | 2.4 MB    | ################################1     |  87%
#
#
#
#
#
# font-ttf-ubuntu-0.83 | 1.5 MB    | ######################8               |  62%
#
#
#
#
#
#
#
# harfbuzz-4.3.0       | 1.1 MB    | ######7                               |  18%
#
# poppler-data-0.4.11  | 2.6 MB    | #####################2                |  57%
#
#
#
#
#
# font-ttf-ubuntu-0.83 | 1.5 MB    | #######################6              |  64%
#
#
#
#
#
#
# conda-24.5.0         | 1.2 MB    | ######5                               |  18%
#
#
#
#
#
#
#
# harfbuzz-4.3.0       | 1.1 MB    | #########4                            |  25%
#
#
# graphviz-2.50.0      | 2.4 MB    | ################################3     |  87%
#
#
#
#
#
# font-ttf-ubuntu-0.83 | 1.5 MB    | ########################3             |  66%
#
#
#
#
#
#
#
# harfbuzz-4.3.0       | 1.1 MB    | ############5                         |  34%
#
# poppler-data-0.4.11  | 2.6 MB    | #####################4                |  58%
#
#
#
#
#
#
# conda-24.5.0         | 1.2 MB    | ######9                               |  19%
#
#
#
#
#
#
#
# harfbuzz-4.3.0       | 1.1 MB    | ###############1                      |  41%
#
#
# graphviz-2.50.0      | 2.4 MB    | ################################5     |  88%
#
#
#
#
#
# font-ttf-ubuntu-0.83 | 1.5 MB    | #########################5            |  69%
#
#
#
#
#
#
#
# harfbuzz-4.3.0       | 1.1 MB    | #################7                    |  48%
#
#
#
#
#
#
# conda-24.5.0         | 1.2 MB    | #######4                              |  20%
#
#
#
#
#
#
#
# harfbuzz-4.3.0       | 1.1 MB    | ####################3                 |  55%
#
# poppler-data-0.4.11  | 2.6 MB    | #####################9                |  59%
#
#
#
#
#
# font-ttf-ubuntu-0.83 | 1.5 MB    | ##########################3           |  71%
#
#
# graphviz-2.50.0      | 2.4 MB    | ################################8     |  89%
#
#
#
#
#
#
# conda-24.5.0         | 1.2 MB    | #######8                              |  21%
#
#
#
#
#
#
#
# harfbuzz-4.3.0       | 1.1 MB    | ######################9               |  62%
#
# poppler-data-0.4.11  | 2.6 MB    | ######################1               |  60%
#
#
#
#
#
# font-ttf-ubuntu-0.83 | 1.5 MB    | ###########################8          |  75%
#
#
#
#
#
#
# conda-24.5.0         | 1.2 MB    | ########3                             |  23%
#
#
# graphviz-2.50.0      | 2.4 MB    | #################################     |  89%
#
#
#
#
#
#
#
# harfbuzz-4.3.0       | 1.1 MB    | ###########################1          |  73%
#
# poppler-data-0.4.11  | 2.6 MB    | ######################3               |  60%
#
#
#
#
#
# font-ttf-ubuntu-0.83 | 1.5 MB    | #############################         |  78%
#
#
#
#
#
#
# conda-24.5.0         | 1.2 MB    | ########8                             |  24%
#
#
#
#
#
#
#
# harfbuzz-4.3.0       | 1.1 MB    | ##############################8       |  83%
#
#
#
#
#
#
#
# harfbuzz-4.3.0       | 1.1 MB    | ####################################  |  97%
#
#
# graphviz-2.50.0      | 2.4 MB    | #################################3    |  90%
#
#
#
#
#
# ...
#
#
#
#
#
#
# conda-24.5.0         | 1.2 MB    | ###########1                          |  30%
#
#
# graphviz-2.50.0      | 2.4 MB    | ##################################    |  92%
#
#
#
#
#
#
#
#
# cairo-1.16.0         | 1.0 MB    | ################9                     |  46%
#
#
#
#
#
# font-ttf-ubuntu-0.83 | 1.5 MB    | ####################################4 |  98%
#
# poppler-data-0.4.11  | 2.6 MB    | ########################1             |  65%
#
#
#
#
#
# font-ttf-ubuntu-0.83 | 1.5 MB    | ##################################### | 100%
#
#
# graphviz-2.50.0      | 2.4 MB    | ##################################3   |  93%
#
#
#
#
#
#
# conda-24.5.0         | 1.2 MB    | ############                          |  33%
#
#
#
#
#
#
#
#
# cairo-1.16.0         | 1.0 MB    | ####################3                 |  55%
#
# poppler-data-0.4.11  | 2.6 MB    | ########################3             |  66%
#
#
#
#
#
#
#
#
#
# font-ttf-source-code | 654 KB    | 9                                     |   2%
#
#
#
#
#
#
#
#
# cairo-1.16.0         | 1.0 MB    | #######################2              |  63%
#
#
#
#
#
#
# conda-24.5.0         | 1.2 MB    | ############5                         |  34%
#
# poppler-data-0.4.11  | 2.6 MB    | ########################6             |  67%
#
#
# graphviz-2.50.0      | 2.4 MB    | ##################################5   |  93%
#
#
#
#
#
#
#
#
#
# font-ttf-source-code | 654 KB    | ###6                                  |  10%
#
#
#
#
#
#
#
#
# cairo-1.16.0         | 1.0 MB    | ##########################5           |  72%
#
# poppler-data-0.4.11  | 2.6 MB    | #########################             |  68%
#
#
#
#
#
#
# conda-24.5.0         | 1.2 MB    | #############4                        |  36%
#
#
#
#
#
#
#
#
#
# font-ttf-source-code | 654 KB    | #####4                                |  15%
#
#
#
#
#
#
#
#
# cairo-1.16.0         | 1.0 MB    | ###############################1      |  84%
#
#
# graphviz-2.50.0      | 2.4 MB    | ##################################7   |  94%
#
# poppler-data-0.4.11  | 2.6 MB    | #########################5            |  69%
#
#
#
#
#
#
#
#
#
# font-ttf-source-code | 654 KB    | ########1                             |  22%
#
#
#
#
#
#
# conda-24.5.0         | 1.2 MB    | ##############3                       |  39%
#
#
# graphviz-2.50.0      | 2.4 MB    | ###################################   |  95%
#
#
#
#
#
#
#
#
# cairo-1.16.0         | 1.0 MB    | ###################################   |  95%
#
# poppler-data-0.4.11  | 2.6 MB    | #########################9            |  70%
#
#
#
#
#
#
#
#
#
# font-ttf-source-code | 654 KB    | ##########8                           |  29%
#
#
#
#
#
#
#
#
# cairo-1.16.0         | 1.0 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
# gdk-pixbuf-2.42.10   | 581 KB    | #                                     |   3%
#
#
#
#
#
#
# conda-24.5.0         | 1.2 MB    | ###############3                      |  41%
#
#
#
#
#
#
#
#
#
# font-ttf-source-code | 654 KB    | #############5                        |  37%
#
# poppler-data-0.4.11  | 2.6 MB    | ##########################4           |  71%
#
#
# graphviz-2.50.0      | 2.4 MB    | ###################################2  |  95%
#
#
#
#
#
#
#
#
#
#
# gdk-pixbuf-2.42.10   | 581 KB    | #########1                            |  25%
#
#
#
#
#
#
#
#
#
# font-ttf-source-code | 654 KB    | ################2                     |  44%
#
#
#
#
#
#
#
#
#
#
# gdk-pixbuf-2.42.10   | 581 KB    | #################3                    |  47%
#
#
#
#
#
#
# conda-24.5.0         | 1.2 MB    | ################2                     |  44%
#
#
# graphviz-2.50.0      | 2.4 MB    | ###################################5  |  96%
#
# poppler-data-0.4.11  | 2.6 MB    | ##########################8           |  73%
#
#
#
#
#
#
#
#
#
#
# gdk-pixbuf-2.42.10   | 581 KB    | ########################4             |  66%
#
#
#
#
#
#
# conda-24.5.0         | 1.2 MB    | ################7                     |  45%
#
#
#
#
#
#
#
#
#
# font-ttf-source-code | 654 KB    | ###################9                  |  54%
#
# poppler-data-0.4.11  | 2.6 MB    | ###########################3          |  74%
#
#
#
#
#
#
#
#
#
#
# gdk-pixbuf-2.42.10   | 581 KB    | ###############################5      |  85%
#
#
# graphviz-2.50.0      | 2.4 MB    | ###################################7  |  97%
#
#
#
#
#
#
#
#
#
# font-ttf-source-code | 654 KB    | #######################5              |  64%
#
#
#
#
#
#
# conda-24.5.0         | 1.2 MB    | #################6                    |  48%
#
# poppler-data-0.4.11  | 2.6 MB    | ###########################7          |  75%
#
#
#
#
#
#
#
#
#
# font-ttf-source-code | 654 KB    | ###########################1          |  73%
#
#
#
#
#
#
#
#
#
#
# gdk-pixbuf-2.42.10   | 581 KB    | ##################################### | 100%
#
#
# graphviz-2.50.0      | 2.4 MB    | ####################################  |  97%
#
#
#
#
#
#
#
#
#
#
#
# libtool-2.4.6        | 422 KB    | #4                                    |   4%
#
#
#
#
#
#
# conda-24.5.0         | 1.2 MB    | ##################5                   |  50%
#
#
#
#
#
#
#
#
#
# font-ttf-source-code | 654 KB    | #############################8        |  81%
#
# poppler-data-0.4.11  | 2.6 MB    | ############################2         |  76%
#
#
#
#
#
#
#
#
#
#
#
# libtool-2.4.6        | 422 KB    | ##################2                   |  49%
#
#
# graphviz-2.50.0      | 2.4 MB    | ####################################2 |  98%
#
#
#
#
#
#
#
#
#
# font-ttf-source-code | 654 KB    | ################################5     |  88%
#
#
#
#
#
#
# conda-24.5.0         | 1.2 MB    | ###################5                  |  53%
#
# poppler-data-0.4.11  | 2.6 MB    | ############################6         |  77%
#
#
# graphviz-2.50.0      | 2.4 MB    | ####################################4 |  99%
#
#
#
#
#
#
#
#
#
#
#
# libtool-2.4.6        | 422 KB    | ################################2     |  87%
#
#
#
#
#
#
#
#
#
# font-ttf-source-code | 654 KB    | ####################################1 |  98%
#
#
#
#
#
#
# conda-24.5.0         | 1.2 MB    | ####################4                 |  55%
#
# poppler-data-0.4.11  | 2.6 MB    | #############################         |  79%
#
#
#
#
#
#
#
#
#
# font-ttf-source-code | 654 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
# libtool-2.4.6        | 422 KB    | ##################################### | 100%
#
#
# graphviz-2.50.0      | 2.4 MB    | ####################################7 |  99%
#
#
#
#
#
#
#
#
#
#
#
#
#
# font-ttf-dejavu-sans | 335 KB    | #7                                    |   5%
#
# poppler-data-0.4.11  | 2.6 MB    | #############################5        |  80%
#
#
#
#
#
#
#
#
#
#
#
#
# pango-1.50.7         | 402 KB    | #4                                    |   4%
#
#
#
#
#
#
#
#
#
#
#
#
#
# font-ttf-dejavu-sans | 335 KB    | ##########6                           |  29%
#
#
# graphviz-2.50.0      | 2.4 MB    | ##################################### | 100%
#
#
# graphviz-2.50.0      | 2.4 MB    | ##################################### | 100%
#
#
#
#
#
#
# conda-24.5.0         | 1.2 MB    | #####################3                |  58%
#
#
#
#
#
#
#
#
#
#
#
#
# pango-1.50.7         | 402 KB    | #####8                                |  16%
#
#
#
#
#
#
#
#
#
#
#
#
#
# font-ttf-dejavu-sans | 335 KB    | ##########################5           |  72%
#
#
#
#
#
#
#
#
#
#
#
#
#
# font-ttf-dejavu-sans | 335 KB    | ##################################### | 100%
#
# poppler-data-0.4.11  | 2.6 MB    | #############################9        |  81%
#
#
#
#
#
#
#
#
#
#
#
#
# pango-1.50.7         | 402 KB    | ###########7                          |  32%
#
#
#
#
#
#
# conda-24.5.0         | 1.2 MB    | ######################2               |  60%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# fontconfig-2.14.1    | 254 KB    | ##3                                   |   6%
#
# poppler-data-0.4.11  | 2.6 MB    | ##############################4       |  82%
#
#
#
#
#
#
#
#
#
#
#
#
# pango-1.50.7         | 402 KB    | ################1                     |  44%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# fontconfig-2.14.1    | 254 KB    | ################2                     |  44%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# gts-0.7.6            | 287 KB    | ##                                    |   6%
#
#
#
#
#
#
# conda-24.5.0         | 1.2 MB    | #######################2              |  63%
#
# poppler-data-0.4.11  | 2.6 MB    | ##############################8       |  83%
#
#
#
#
#
#
#
#
#
#
#
#
# pango-1.50.7         | 402 KB    | #######################5              |  64%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# fontconfig-2.14.1    | 254 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# fontconfig-2.14.1    | 254 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# nspr-4.35            | 243 KB    | ##4                                   |   7%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# gts-0.7.6            | 287 KB    | ####1                                 |  11%
#
# poppler-data-0.4.11  | 2.6 MB    | ###############################3      |  85%
#
#
#
#
#
#
# conda-24.5.0         | 1.2 MB    | ########################6             |  67%
#
#
#
#
#
#
#
#
#
#
#
#
# pango-1.50.7         | 402 KB    | #############################4        |  80%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# nspr-4.35            | 243 KB    | #############################1        |  79%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# gts-0.7.6            | 287 KB    | ######1                               |  17%
#
# poppler-data-0.4.11  | 2.6 MB    | ###############################7      |  86%
#
#
#
#
#
#
# conda-24.5.0         | 1.2 MB    | #########################5            |  69%
#
#
#
#
#
#
#
#
#
#
#
#
# pango-1.50.7         | 402 KB    | ###################################3  |  95%
#
#
#
#
#
#
#
#
#
#
#
#
# pango-1.50.7         | 402 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# nspr-4.35            | 243 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libgd-2.3.3          | 200 KB    | ##9                                   |   8%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# gts-0.7.6            | 287 KB    | ########2                             |  22%
#
# poppler-data-0.4.11  | 2.6 MB    | ################################2     |  87%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pixman-0.40.0        | 196 KB    | ###                                   |   8%
#
#
#
#
#
#
# conda-24.5.0         | 1.2 MB    | ##########################4           |  72%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libgd-2.3.3          | 200 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libgd-2.3.3          | 200 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# certifi-2024.6.2     | 162 KB    | ###6                                  |  10%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pixman-0.40.0        | 196 KB    | ###############                       |  41%
#
# poppler-data-0.4.11  | 2.6 MB    | ################################6     |  88%
#
#
#
#
#
#
# conda-24.5.0         | 1.2 MB    | ###########################3          |  74%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# certifi-2024.6.2     | 162 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# expat-2.6.2          | 150 KB    | ###9                                  |  11%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# gts-0.7.6            | 287 KB    | ############3                         |  33%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pixman-0.40.0        | 196 KB    | ##############################1       |  82%
#
# poppler-data-0.4.11  | 2.6 MB    | #################################1    |  90%
#
#
#
#
#
#
# conda-24.5.0         | 1.2 MB    | ############################3         |  77%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# expat-2.6.2          | 150 KB    | ###########################6          |  75%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pixman-0.40.0        | 196 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# gts-0.7.6            | 287 KB    | ################4                     |  45%
#
# poppler-data-0.4.11  | 2.6 MB    | #################################7    |  91%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# expat-2.6.2          | 150 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ca-certificates-2024 | 128 KB    | ####6                                 |  12%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
# conda-24.5.0         | 1.2 MB    | #############################7        |  80%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ca-certificates-2024 | 128 KB    | #############8                        |  37%
#
# poppler-data-0.4.11  | 2.6 MB    | ##################################2   |  93%
#
#
#
#
#
#
# conda-24.5.0         | 1.2 MB    | ##############################6       |  83%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# gts-0.7.6            | 287 KB    | ####################5                 |  56%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ca-certificates-2024 | 128 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ca-certificates-2024 | 128 KB    | ##################################### | 100%
#
# poppler-data-0.4.11  | 2.6 MB    | ##################################6   |  94%
#
#
#
#
#
#
# conda-24.5.0         | 1.2 MB    | ###############################5      |  85%
#
# poppler-data-0.4.11  | 2.6 MB    | ###################################3  |  96%
#
#
#
#
#
#
# conda-24.5.0         | 1.2 MB    | ################################5     |  88%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# gts-0.7.6            | 287 KB    | ########################7             |  67%
#
# poppler-data-0.4.11  | 2.6 MB    | ###################################8  |  97%
#
#
#
#
#
#
# conda-24.5.0         | 1.2 MB    | #################################8    |  92%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# gts-0.7.6            | 287 KB    | ############################8         |  78%
#
# poppler-data-0.4.11  | 2.6 MB    | ####################################4 |  99%
#
#
#
#
#
#
# conda-24.5.0         | 1.2 MB    | ##################################8   |  94%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# gts-0.7.6            | 287 KB    | ################################9     |  89%
#
# poppler-data-0.4.11  | 2.6 MB    | ##################################### | 100%
#
# poppler-data-0.4.11  | 2.6 MB    | ##################################### | 100%
#
#
#
#
#
#
# conda-24.5.0         | 1.2 MB    | ####################################2 |  98%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# gts-0.7.6            | 287 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# gts-0.7.6            | 287 KB    | ##################################### | 100%
#
#
#
#
#
#
# conda-24.5.0         | 1.2 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
#
# Note: you may need to restart the kernel to use updated packages.

# %%
import pydotplus
dot_data = export_graphviz(clf, out_file = None, feature_names = iris.feature_names, class_names = iris.target_names)
graph = pydotplus.graph_from_dot_data(dot_data)
graph.write_pdf("iris.pdf")
# Out:
# True

# %%
y_train_pred = clf.predict(X_train)
y_test_pred = clf.predict(X_test)

# %%
from sklearn.metrics import confusion_matrix

# %%
confusion_matrix(Y_train, y_train_pred)
# Out:
# array([[37,  0,  0],
#        [ 0, 34,  0],
#        [ 0,  0, 41]])

# %%
confusion_matrix(Y_test, y_test_pred)
# Out:
# array([[13,  0,  0],
#        [ 0, 15,  1],
#        [ 0,  0,  9]])
