# %%
from sklearn import datasets
from sklearn.model_selection import train_test_split

# %%
iris = datasets.load_iris()
X = iris.data
Y = iris.target

# %%
x_train, x_test, y_train, y_test = train_test_split(X,Y, random_state = 1)

# %%
from sklearn.neural_network import MLPClassifier

# %%
clf = MLPClassifier(hidden_layer_sizes = (20,), max_iter = 3000)
clf.fit(x_train, y_train)
# Out:
# MLPClassifier(hidden_layer_sizes=(20,), max_iter=3000)

# %%
clf.score(x_test, y_test)
# Out:
# 1.0

# %%
clf.coefs_ # dont include biases
# Out:
# [array([[-1.48877505e-02, -1.81489569e-02,  1.84359115e-01,
#           1.61264963e-01,  9.02577347e-01, -1.11868583e-19,
#           3.43817290e-01,  2.05702356e-01,  4.37694697e-01,
#           1.50500608e-01, -5.80102657e-01, -1.85287812e-03,
#          -1.72115415e-01,  4.60638032e-01,  7.77941062e-02,
#          -2.57004701e-01,  2.12087167e-01,  5.21221854e-01,
#           2.98273294e-01,  1.23249282e-01],
#         [ 2.80804484e-17, -6.37462764e-04, -1.35925347e-02,
#           7.54777526e-01, -1.15173414e-01, -1.39093391e-02,
#           7.33462264e-01, -8.67745450e-02,  4.10678232e-01,
#          -3.00761596e-01, -1.36569572e-01, -1.12209424e-07,
#           1.68905364e-02,  4.60324151e-01,  1.46013377e-01,
#           3.06370844e-01,  2.88731123e-01,  4.40586665e-01,
#           4.76565533e-01,  4.35045950e-01],
#         [-8.96167039e-06,  1.57303826e-05,  3.96929160e-01,
#          -7.74972730e-01,  3.57616455e-01, -8.92934725e-05,
# ...

# %%
len(clf.coefs_) # num of layers
# Out:
# 2

# %%
clf.coefs_[0].shape, clf.coefs_[1].shape
# Out:
# ((4, 20), (20, 3))

# %%
clf.intercepts_[0].shape, clf.intercepts_[1].shape #bias
# Out:
# ((20,), (3,))
